# %%
import sys
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
sys.path.append("../modules/semantic-segmentation")
from segmentor import Segmentor
seg = Segmentor()
classes_output, img_viz = seg.semantic_segmentation(image=image, visualization=True)
# Out:
# 2024-04-10 11:15:46.186649: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-10 11:15:47.275956: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[1], line 5
#       3 tf.disable_v2_behavior()
#       4 sys.path.append("../modules/semantic-segmentation")
# ----> 5 from segmentor import Segmentor
#       6 seg = Segmentor()
#       7 classes_output, img_viz = seg.semantic_segmentation(image=image, visualization=True)
#
# File /workspace/examples/../modules/semantic-segmentation/segmentor.py:12
#       1 #
#       2 # Semantic Segmentator
#       3 # Class for driving image segmentation
#    (...)
#       8 # (c) Yongyang Nie 2018
#       9 #
# ---> 12 import models.enet_naive_upsampling.model as enet
#      13 import utils as utils
#      14 import configs as configs
#
# File /workspace/examples/../modules/semantic-segmentation/models/__init__.py:2
#       1 # coding=utf-8
# ----> 2 import keras
#       3 from keras.utils import plot_model
#       6 def select_model(model_name):
#
# File /usr/local/lib/python3.10/dist-packages/keras/__init__.py:3
#       1 from __future__ import absolute_import
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# File /usr/local/lib/python3.10/dist-packages/keras/utils/__init__.py:26
#      24 from .layer_utils import get_source_inputs
#      25 from .layer_utils import print_summary
# ---> 26 from .vis_utils import model_to_dot
#      27 from .vis_utils import plot_model
#      28 from .np_utils import to_categorical
#
# File /usr/local/lib/python3.10/dist-packages/keras/utils/vis_utils.py:7
#       4 from __future__ import print_function
#       6 import os
# ----> 7 from ..models import Model
#       8 from ..layers.wrappers import Wrapper
#      10 # `pydot` is an optional dependency,
#      11 # see `extras_require` in `setup.py`.
#
# File /usr/local/lib/python3.10/dist-packages/keras/models.py:12
#      10 from .engine.input_layer import Input
#      11 from .engine.input_layer import InputLayer
# ---> 12 from .engine.training import Model
#      13 from .engine.sequential import Sequential
#      14 from .engine.saving import save_model
#
# File /usr/local/lib/python3.10/dist-packages/keras/engine/__init__.py:8
#       6 from .base_layer import Layer
#       7 from .network import get_source_inputs
# ----> 8 from .training import Model
#
# File /usr/local/lib/python3.10/dist-packages/keras/engine/training.py:14
#      12 from .network import Network
#      13 from .base_layer import Layer
# ---> 14 from . import training_utils
#      15 from . import training_arrays
#      16 from . import training_generator
#
# File /usr/local/lib/python3.10/dist-packages/keras/engine/training_utils.py:17
#      15 from .. import backend as K
#      16 from .. import losses
# ---> 17 from .. import metrics as metrics_module
#      18 from ..utils import Sequence
#      19 from ..utils import generic_utils
#
# File /usr/local/lib/python3.10/dist-packages/keras/metrics.py:1850
#    1848     import tensorflow as tf
#    1849     if tf.__version__ >= '2.0.0':
# -> 1850         BaseMeanIoU = tf.keras.metrics.MeanIoU
#    1853 class MeanIoU(BaseMeanIoU):
#    1854     """Computes the mean Intersection-Over-Union metric.
#    1855
#    1856     Mean Intersection-Over-Union is a common evaluation metric for semantic image
#    (...)
#    1881         dtype: (Optional) data type of the metric result.
#    1882     """
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/lazy_loader.py:182, in KerasLazyLoader.__getattr__(self, item)
#     180 if not self._tfll_initialized:
#     181   self._initialize()
# --> 182 if self._tfll_keras_version == "keras_3":
#     183   if (
#     184       self._tfll_mode == "v1"
#     185       and not self._tfll_submodule
#     186       and item.startswith("compat.v1.")
#     187   ):
#     188     raise AttributeError(
#     189         "`tf.compat.v1.keras` is not available with Keras 3. Keras 3 has "
#     190         "no support for TF 1 APIs. You can install the `tf_keras` package "
#    (...)
#     193         "`tf.compat.v1.keras` to `tf_keras`."
#     194     )
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/lazy_loader.py:182, in KerasLazyLoader.__getattr__(self, item)
#     180 if not self._tfll_initialized:
#     181   self._initialize()
# --> 182 if self._tfll_keras_version == "keras_3":
#     183   if (
#     184       self._tfll_mode == "v1"
#     185       and not self._tfll_submodule
#     186       and item.startswith("compat.v1.")
#     187   ):
#     188     raise AttributeError(
#     189         "`tf.compat.v1.keras` is not available with Keras 3. Keras 3 has "
#     190         "no support for TF 1 APIs. You can install the `tf_keras` package "
#    (...)
#     193         "`tf.compat.v1.keras` to `tf_keras`."
#     194     )
#
#     [... skipping similar frames: KerasLazyLoader.__getattr__ at line 182 (2877 times)]
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/lazy_loader.py:182, in KerasLazyLoader.__getattr__(self, item)
#     180 if not self._tfll_initialized:
#     181   self._initialize()
# --> 182 if self._tfll_keras_version == "keras_3":
#     183   if (
#     184       self._tfll_mode == "v1"
#     185       and not self._tfll_submodule
#     186       and item.startswith("compat.v1.")
#     187   ):
#     188     raise AttributeError(
#     189         "`tf.compat.v1.keras` is not available with Keras 3. Keras 3 has "
#     190         "no support for TF 1 APIs. You can install the `tf_keras` package "
#    (...)
#     193         "`tf.compat.v1.keras` to `tf_keras`."
#     194     )
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/lazy_loader.py:178, in KerasLazyLoader.__getattr__(self, item)
#     177 def __getattr__(self, item):
# --> 178   if item in ("_tfll_mode", "_tfll_initialized", "_tfll_name"):
#     179     return super(types.ModuleType, self).__getattribute__(item)
#     180   if not self._tfll_initialized:
#
# RecursionError: maximum recursion depth exceeded in comparison
